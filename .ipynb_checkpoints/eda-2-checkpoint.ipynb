# %% [markdown]
# EDA with monthly data

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

# %%
months_abv = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %% [markdown]
# ### Global mean temperature change

# %%
global_temp_raw = pd.read_csv('global-temp-monthly.csv')
global_temp_raw
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.19 -0.24 -0.09 -0.16 -0.10 -0.21 -0.18 -0.10 -0.14 -0.23 -0.21
# 1    1881 -0.20 -0.14  0.03  0.05  0.06 -0.19  0.00 -0.04 -0.15 -0.22 -0.19
# 2    1882  0.16  0.14  0.05 -0.17 -0.14 -0.23 -0.16 -0.07 -0.14 -0.23 -0.16
# 3    1883 -0.29 -0.37 -0.12 -0.18 -0.17 -0.08 -0.06 -0.14 -0.21 -0.11 -0.23
# 4    1884 -0.13 -0.07 -0.36 -0.40 -0.34 -0.36 -0.30 -0.27 -0.27 -0.25 -0.33
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 139  2019  0.93  0.95  1.17  1.01  0.85  0.90  0.94  0.95  0.92  1.00  0.99
# 140  2020  1.17  1.24  1.17  1.13  1.01  0.92  0.90  0.87  0.98  0.88  1.10
# 141  2021  0.81  0.64  0.89  0.75  0.78  0.84  0.92  0.82  0.92  1.00  0.94
# 142  2022  0.91  0.89  1.05  0.84  0.84  0.92  0.94  0.95  0.89  0.96  0.72
# 143  2023  0.87  0.98  1.20  1.00  0.94  1.08  1.19  1.19  1.48  1.34  1.43
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0   -0.18 -0.17   ***   *** -0.12 -0.16 -0.19
# 1   -0.07 -0.09  -.10  -.17  0.05 -0.08 -0.19
# 2   -0.35 -0.11  -.09   .08 -0.09 -0.15 -0.18
# 3   -0.11 -0.17  -.19  -.34 -0.16 -0.09 -0.18
# 4   -0.30 -0.28  -.27  -.10 -0.37 -0.31 -0.28
# ..    ...   ...   ...   ...   ...   ...   ...
# 139  1.09  0.98   .96   .93  1.01  0.93  0.97
# 140  0.80  1.01  1.04  1.17  1.10  0.89  0.99
# 141  0.86  0.85   .84   .75  0.81  0.86  0.95
# 142  0.80  0.89   .90   .89  0.91  0.94  0.86
# 143  1.37  1.17  1.12   .88  1.05  1.15  1.41
#
# [144 rows x 19 columns]

# %%
# Melt the identifier variables in the columns for tidy data
global_temp = pd.melt(global_temp_raw, id_vars=['Year'], value_vars=months_abv)
global_temp = global_temp.rename(columns={'Year': 'year', 'variable': 'month', 'value': 'temp_change'})
global_temp
# Out:
#       year month  temp_change
# 0     1880   Jan        -0.19
# 1     1881   Jan        -0.20
# 2     1882   Jan         0.16
# 3     1883   Jan        -0.29
# 4     1884   Jan        -0.13
# ...    ...   ...          ...
# 1723  2019   Dec         1.09
# 1724  2020   Dec         0.80
# 1725  2021   Dec         0.86
# 1726  2022   Dec         0.80
# 1727  2023   Dec         1.37
#
# [1728 rows x 3 columns]

# %%
plt.figure(figsize=(20,15))
plt.plot(global_temp['temp_change'])

# %% [markdown]
# ### Electricity generation
#
# In this dataset, a month of 13 means a yearly total. We should only consider the data that is not aggregated by yearly total, which appears to start in 1971 (not verified).

# %%
elec_raw = pd.read_csv('electricity-monthly.csv')
elec_raw
# Out:
#           MSN  YYYYMM      Value  Column_Order  \
# 0     FFPRBUS  194913  28.740479             1
# 1     FFPRBUS  195013  32.553205             1
# 2     FFPRBUS  195113  35.782118             1
# 3     FFPRBUS  195213  34.964662             1
# 4     FFPRBUS  195313  35.338361             1
# ...       ...     ...        ...           ...
# 8191  TETCBUS  202305   7.355335            12
# 8192  TETCBUS  202306   7.480637            12
# 8193  TETCBUS  202307   8.089976            12
# 8194  TETCBUS  202308   8.234984            12
# 8195  TETCBUS  202309   7.410390            12
#
#                            Description             Unit
# 0        Total Fossil Fuels Production  Quadrillion Btu
# 1        Total Fossil Fuels Production  Quadrillion Btu
# 2        Total Fossil Fuels Production  Quadrillion Btu
# 3        Total Fossil Fuels Production  Quadrillion Btu
# 4        Total Fossil Fuels Production  Quadrillion Btu
# ...                                ...              ...
# 8191  Total Primary Energy Consumption  Quadrillion Btu
# 8192  Total Primary Energy Consumption  Quadrillion Btu
# 8193  Total Primary Energy Consumption  Quadrillion Btu
# 8194  Total Primary Energy Consumption  Quadrillion Btu
# 8195  Total Primary Energy Consumption  Quadrillion Btu
#
# [8196 rows x 6 columns]

# %%
elec_raw[elec_raw['YYYYMM'] > 197101]
# Out:
#           MSN  YYYYMM      Value  Column_Order  \
# 22    FFPRBUS  197113  58.010670             1
# 23    FFPRBUS  197213  58.904079             1
# 24    FFPRBUS  197301   4.932632             1
# 25    FFPRBUS  197302   4.729582             1
# 26    FFPRBUS  197303   4.946902             1
# ...       ...     ...        ...           ...
# 8191  TETCBUS  202305   7.355335            12
# 8192  TETCBUS  202306   7.480637            12
# 8193  TETCBUS  202307   8.089976            12
# 8194  TETCBUS  202308   8.234984            12
# 8195  TETCBUS  202309   7.410390            12
#
#                            Description             Unit
# 22       Total Fossil Fuels Production  Quadrillion Btu
# 23       Total Fossil Fuels Production  Quadrillion Btu
# 24       Total Fossil Fuels Production  Quadrillion Btu
# 25       Total Fossil Fuels Production  Quadrillion Btu
# 26       Total Fossil Fuels Production  Quadrillion Btu
# ...                                ...              ...
# 8191  Total Primary Energy Consumption  Quadrillion Btu
# 8192  Total Primary Energy Consumption  Quadrillion Btu
# 8193  Total Primary Energy Consumption  Quadrillion Btu
# 8194  Total Primary Energy Consumption  Quadrillion Btu
# 8195  Total Primary Energy Consumption  Quadrillion Btu
#
# [7932 rows x 6 columns]

# %%
# elec[elec['CODE_TIME'] == 'JAN2010' ]
elec_raw
# Out:
#               COUNTRY CODE_TIME           TIME  YEAR  MONTH MONTH_NAME  \
# 0           Australia   JAN2010   January 2010  2010      1    January
# 1           Australia   JAN2010   January 2010  2010      1    January
# 2           Australia   JAN2010   January 2010  2010      1    January
# 3           Australia   JAN2010   January 2010  2010      1    January
# 4           Australia   JAN2010   January 2010  2010      1    January
# ...               ...       ...            ...   ...    ...        ...
# 181910  United States   DEC2022  December 2022  2022     12   December
# 181911  United States   DEC2022  December 2022  2022     12   December
# 181912  United States   DEC2022  December 2022  2022     12   December
# 181913  United States   DEC2022  December 2022  2022     12   December
# 181914  United States   DEC2022  December 2022  2022     12   December
#
#                             PRODUCT          VALUE  DISPLAY_ORDER  \
# 0                             Hydro     990.728000              1
# 1                              Wind     409.469000              2
# 2                             Solar      49.216000              3
# 3                        Geothermal       0.083000              4
# 4           Total combustible fuels   19289.730000              7
# ...                             ...            ...            ...
# 181910               Non-renewables  292417.548132             23
# 181911                       Others    8017.840957             24
# 181912  Other renewables aggregated    6133.265943             25
# 181913                   Low carbon  146425.474534             26
# 181914                 Fossil fuels  223357.219650             27
#
#           yearToDate  previousYearToDate     share
# 0       1.647189e+04                 NaN  0.047771
# 1       4.940909e+03                 NaN  0.019744
# 2       9.082380e+02                 NaN  0.002373
# 3       9.960000e-01                 NaN  0.000004
# 4       2.143030e+05                 NaN  0.930108
# ...              ...                 ...       ...
# 181910  3.355042e+06        3.320634e+06  0.791164
# 181911  5.393606e+04        4.899452e+04  0.021693
# 181912  7.100997e+04        7.242158e+04  0.016594
# 181913  1.749805e+06        1.670531e+06  0.396168
# 181914  2.583925e+06        2.542138e+06  0.604315
#
# [181915 rows x 12 columns]

# %% [markdown]
# ### Greenhouse Gas (Carbon Dioxide)

# %%
co2_raw = pd.read_csv('co2-monthly.csv', comment = '#')
co2_raw
# Out:
#      year  month   decimal  average  average_unc   trend  trend_unc
# 0    1979      1  1979.042   336.56         0.11  335.92       0.09
# 1    1979      2  1979.125   337.29         0.09  336.25       0.10
# 2    1979      3  1979.208   337.88         0.11  336.51       0.10
# 3    1979      4  1979.292   338.32         0.12  336.72       0.10
# 4    1979      5  1979.375   338.26         0.03  336.71       0.10
# ..    ...    ...       ...      ...          ...     ...        ...
# 533  2023      6  2023.458   419.57         0.10  418.98       0.06
# 534  2023      7  2023.542   417.85         0.10  419.14       0.06
# 535  2023      8  2023.625   416.59         0.10  419.41       0.06
# 536  2023      9  2023.708   416.99         0.10  419.80       0.06
# 537  2023     10  2023.792   418.64         0.10  420.20       0.06
#
# [538 rows x 7 columns]

# %%
plt.plot(co2_raw["average"])

# %% [markdown]
# ### Greenhouse Gas (Methane)

# %%
ch4_raw = pd.read_csv('ch4-monthly.csv', comment = '#')
ch4_raw
# Out:
#      year  month   decimal  average  average_unc    trend  trend_unc
# 0    1983      7  1983.542  1625.94         2.26  1634.88       1.45
# 1    1983      8  1983.625  1628.06         2.88  1635.45       1.39
# 2    1983      9  1983.708  1638.44         2.34  1636.07       1.32
# 3    1983     10  1983.792  1644.79         1.50  1636.75       1.24
# 4    1983     11  1983.875  1642.60         0.73  1637.49       1.16
# ..    ...    ...       ...      ...          ...      ...        ...
# 478  2023      5  2023.375  1920.00        -9.99  1922.60      -9.99
# 479  2023      6  2023.458  1915.94        -9.99  1923.72      -9.99
# 480  2023      7  2023.542  1914.56        -9.99  1924.85      -9.99
# 481  2023      8  2023.625  1919.15        -9.99  1926.00      -9.99
# 482  2023      9  2023.708  1927.35        -9.99  1927.13      -9.99
#
# [483 rows x 7 columns]

# %%
plt.plot(ch4_raw["average"])
